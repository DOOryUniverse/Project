# %%
import pandas as pd
# !pip install pmdarima
# !pip install plotly
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
import numpy as np
from pmdarima.arima import ndiffs
import pmdarima as pm
from sklearn.metrics import mean_squared_error
air_hour = pd.read_csv('./air_hour.csv')
air_hour.set_index('date', inplace = True)
air_hour.index = pd.to_datetime(air_hour.index)

# %%
columns = ["AK_close", "korea_air_close", "aisana_close", "airbusan_close", "jeju_close", "jin_close", "tway_close" ]
title = ["AK 홀딩스(006840)", "대한항공(003490)", "아시아나항공(020560)", "에어부산(298690)", "제주항공(089090)", "진에어(272450)", "티웨이항공(091810)"]


for i in range(0,7,1):
    # print("="*60)
    # print(i)
    a = title[i]
   
    y_train = air_hour[columns[i]].iloc[:1504] #기준행 1504 
    y_test = air_hour[columns[i]].iloc[1504:]
    y_train.plot()
    y_test.plot()

    #차분 차수 찾기
    kpss_diffs = ndiffs(y_train, alpha=0.05 , test='kpss', max_d = 6)
    adf_diffs = ndiffs(y_train, alpha=0.05, test='adf', max_d=6)
    n_diffs = max(adf_diffs,kpss_diffs)

    n_diffs_print = f'적정 차분 차수는 {n_diffs}'
    
    print(n_diffs_print)

    model = pm.auto_arima(y=y_train, 
                    d = 1,
                    start_p=0,
                    max_p=3,
                    start_q=0,
                    max_q=3,
                    seasonal=False,
                    stepwise=True,
                    trace = True)
    
    #append위한 함수
    def model2():
        model = pm.auto_arima(y=y_train, 
                    d = 1,
                    start_p=0,
                    max_p=3,
                    start_q=0,
                    max_q=3,
                    seasonal=False,
                    stepwise=True,
                    trace = True)
        return model

    # print_data.append(model2())
    
    model.fit(y_train)
    print(model.summary())

    model.plot_diagnostics(figsize=(16,8))
    plt.show()

    y_predict = model.predict(n_periods=len(y_test))
    y_predict = pd.DataFrame(y_predict, index=y_test.index, columns=['Prediction'])
    y_predict

 
    def forcast_one_step():
      fc, conf_int = model.predict(n_periods=1, return_conf_int=True)
    
      return (fc.tolist()[0] , np.asarray(conf_int).tolist()[0] )
    


    forcast_one_step()
    
    forcast_list=[]
    y_pred = []
    pred_upper=[] 
    pred_lower = []

    y_pred_1 = []
    pred_upper_1=[] 
    pred_lower_1 = []

    for i in y_test:
      fc , conf = forcast_one_step()
      #fc_1, conf_1 = arima_model()
      y_pred.append(fc)
      pred_upper.append(conf[1])
      pred_lower.append(conf[0])
      
    
      model.update(i)
    
  
    print(f"평균 절대 비율 오차: {np.mean(np.abs((y_test - y_pred) / y_test)) * 100:.2f}")
    print(f"평균 괴리율: {np.mean((y_pred - y_test) / y_test) *100:.3f} %")

    import plotly.graph_objects as go
    fig = go.Figure([
        go.Scatter(x=y_train.index , y=y_train, name='Train', mode='lines',line=dict(color='royalblue')),
        #테스트데이터
        go.Scatter(x=y_test.index , y=y_test, name='Test', mode='lines',line=dict(color='red')),
        #predict 데이터
        go.Scatter(x=y_test.index , y=y_pred, name='Prediction', mode='lines',line=dict(color='yellow', dash='dot', width=3)),
        #신뢰구간
        go.Scatter(x=y_test.index.tolist() + y_test.index[::-1].tolist() , 
                y= pred_upper + pred_lower[::-1],
               fill='toself',
                fillcolor='rgba(0,0,30,0.1)',
                line={'color':'rgba(0,0,0,0)'}, 
                hoverinfo="skip",
                showlegend=True
              )
                ])

    fig.update_layout(height=400 , width=1000, title_text=a)
    fig.show()
    print("="*120)
# Out:
# 적정 차분 차수는 1
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=20660.670, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=20651.569, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=20650.422, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=20659.376, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=20651.717, Time=0.25 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=20650.393, Time=0.14 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=20650.377, Time=0.47 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=20643.939, Time=1.19 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=20649.137, Time=0.57 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=20643.540, Time=1.28 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=20642.095, Time=0.76 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=20646.903, Time=0.15 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=20648.614, Time=0.11 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=20640.760, Time=0.28 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=20647.996, Time=0.33 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=20645.732, Time=0.08 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=20642.199, Time=0.43 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=20647.520, Time=0.05 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=20642.635, Time=0.50 sec
#
# Best model:  ARIMA(3,1,1)(0,0,0)[0]
# Total fit time: 6.864 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1504
# Model:               SARIMAX(3, 1, 1)   Log Likelihood              -10315.380
# Date:                Tue, 03 May 2022   AIC                          20640.760
# Time:                        23:58:34   BIC                          20667.336
# Sample:                             0   HQIC                         20650.660
#                                - 1504
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6200      0.114      5.427      0.000       0.396       0.844
# ar.L2          0.0129      0.026      0.492      0.623      -0.038       0.064
# ar.L3          0.0986      0.023      4.234      0.000       0.053       0.144
# ma.L1         -0.7116      0.115     -6.195      0.000      -0.937      -0.486
# sigma2      5.379e+04   1168.322     46.040      0.000    5.15e+04    5.61e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):              1200.81
# Prob(Q):                              0.73   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.39   Skew:                             0.04
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# 평균 절대 비율 오차: 0.73
# 평균 괴리율: -0.014 %
# ========================================================================================================================
# 적정 차분 차수는 1
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=20456.617, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=20447.862, Time=0.15 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=20446.668, Time=0.18 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=20454.677, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=20445.685, Time=1.01 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=20447.261, Time=0.27 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=20447.293, Time=0.29 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=20445.323, Time=0.18 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=20447.293, Time=0.27 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=20449.326, Time=0.33 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=20443.413, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=20444.748, Time=0.07 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=20445.383, Time=0.14 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=20445.385, Time=0.14 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=20443.785, Time=0.23 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=20447.403, Time=0.17 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 3.618 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1504
# Model:               SARIMAX(0, 1, 2)   Log Likelihood              -10218.707
# Date:                Wed, 04 May 2022   AIC                          20443.413
# Time:                        00:00:43   BIC                          20459.359
# Sample:                             0   HQIC                         20449.353
#                                - 1504
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0891      0.015     -5.749      0.000      -0.119      -0.059
# ma.L2         -0.0464      0.024     -1.926      0.054      -0.094       0.001
# sigma2       4.73e+04    775.805     60.970      0.000    4.58e+04    4.88e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              4229.77
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.78   Skew:                             0.00
# Prob(H) (two-sided):                  0.01   Kurtosis:                        11.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning:
#
# marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
# 평균 절대 비율 오차: 0.45
# 평균 괴리율: -0.003 %
# ========================================================================================================================
# 적정 차분 차수는 1
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=20057.185, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=20058.989, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=20058.969, Time=0.17 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=20055.366, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=20059.649, Time=1.02 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.388 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1504
# Model:               SARIMAX(0, 1, 0)   Log Likelihood              -10026.683
# Date:                Wed, 04 May 2022   AIC                          20055.366
# Time:                        00:01:52   BIC                          20060.681
# Sample:                             0   HQIC                         20057.345
#                                - 1504
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      3.645e+04    451.752     80.685      0.000    3.56e+04    3.73e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.20   Jarque-Bera (JB):             14719.86
# Prob(Q):                              0.66   Prob(JB):                         0.00
# Heteroskedasticity (H):               7.83   Skew:                             0.64
# Prob(H) (two-sided):                  0.00   Kurtosis:                        18.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning:
#
# marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
# 평균 절대 비율 오차: 0.69
# 평균 괴리율: 0.000 %
# ========================================================================================================================
# 적정 차분 차수는 1
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=14831.424, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=14830.567, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=14829.816, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=14829.949, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=14834.916, Time=0.49 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=14813.559, Time=0.48 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=14813.345, Time=0.64 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=14770.318, Time=1.81 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=14811.351, Time=0.80 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=14769.740, Time=2.29 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=14809.766, Time=0.89 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=14761.878, Time=2.55 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=14766.708, Time=2.74 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=14761.023, Time=1.60 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=14765.422, Time=1.58 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=14768.404, Time=1.10 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=14769.056, Time=0.86 sec
#
# Best model:  ARIMA(3,1,3)(0,0,0)[0]
# Total fit time: 18.096 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1504
# Model:               SARIMAX(3, 1, 3)   Log Likelihood               -7373.511
# Date:                Wed, 04 May 2022   AIC                          14761.023
# Time:                        00:02:28   BIC                          14798.229
# Sample:                             0   HQIC                         14774.882
#                                - 1504
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6096      0.053     11.559      0.000       0.506       0.713
# ar.L2         -1.0106      0.019    -53.695      0.000      -1.047      -0.974
# ar.L3          0.2833      0.052      5.444      0.000       0.181       0.385
# ma.L1         -0.6819      0.050    -13.679      0.000      -0.780      -0.584
# ma.L2          1.0389      0.017     61.034      0.000       1.006       1.072
# ma.L3         -0.4369      0.050     -8.777      0.000      -0.534      -0.339
# sigma2      1084.1850      8.624    125.722      0.000    1067.283    1101.087
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):            353233.38
# Prob(Q):                              0.75   Prob(JB):                         0.00
# Heteroskedasticity (H):               7.52   Skew:                             4.00
# Prob(H) (two-sided):                  0.00   Kurtosis:                        77.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning:
#
# marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
# 평균 절대 비율 오차: 0.61
# 평균 괴리율: 0.001 %
# ========================================================================================================================
# 적정 차분 차수는 1
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=20310.557, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=20303.010, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=20301.986, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=20308.804, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=20299.304, Time=0.81 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=20300.995, Time=0.54 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=20300.968, Time=0.89 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=20300.207, Time=0.18 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=20301.442, Time=0.16 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=20294.165, Time=2.35 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=20292.816, Time=2.41 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=20302.003, Time=0.62 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=20297.923, Time=1.37 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=20292.724, Time=2.62 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=20302.493, Time=0.76 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=20291.098, Time=1.04 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=20300.796, Time=0.75 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=20292.542, Time=0.75 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=20296.191, Time=0.91 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=20299.296, Time=0.40 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=20291.092, Time=1.33 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=20300.297, Time=0.29 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=20299.246, Time=0.35 sec
#
# Best model:  ARIMA(3,1,2)(0,0,0)[0]
# Total fit time: 18.924 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1504
# Model:               SARIMAX(3, 1, 2)   Log Likelihood              -10139.546
# Date:                Wed, 04 May 2022   AIC                          20291.092
# Time:                        00:06:17   BIC                          20322.984
# Sample:                             0   HQIC                         20302.972
#                                - 1504
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.3179      0.054     24.412      0.000       1.212       1.424
# ar.L2         -0.8151      0.042    -19.336      0.000      -0.898      -0.732
# ar.L3         -0.0595      0.020     -2.952      0.003      -0.099      -0.020
# ma.L1         -1.4088      0.052    -26.854      0.000      -1.512      -1.306
# ma.L2          0.8974      0.047     19.238      0.000       0.806       0.989
# sigma2      4.238e+04    603.179     70.268      0.000    4.12e+04    4.36e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             11522.59
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.94   Skew:                            -0.33
# Prob(H) (two-sided):                  0.45   Kurtosis:                        16.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning:
#
# marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
# 평균 절대 비율 오차: 0.86
# 평균 괴리율: -0.028 %
# ========================================================================================================================
# 적정 차분 차수는 1
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=20598.516, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=20598.248, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=20598.150, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=20596.631, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=20599.849, Time=0.62 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.017 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1504
# Model:               SARIMAX(0, 1, 0)   Log Likelihood              -10297.316
# Date:                Wed, 04 May 2022   AIC                          20596.631
# Time:                        00:09:14   BIC                          20601.947
# Sample:                             0   HQIC                         20598.611
#                                - 1504
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      5.225e+04    813.605     64.221      0.000    5.07e+04    5.38e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.90   Jarque-Bera (JB):              5052.14
# Prob(Q):                              0.17   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.61   Skew:                            -0.38
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning:
#
# marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
# 평균 절대 비율 오차: 0.84
# 평균 괴리율: -0.005 %
# ========================================================================================================================
# 적정 차분 차수는 1
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=15255.094, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=15256.830, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=15256.830, Time=0.19 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=15253.154, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=15258.837, Time=0.16 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.526 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1504
# Model:               SARIMAX(0, 1, 0)   Log Likelihood               -7625.577
# Date:                Wed, 04 May 2022   AIC                          15253.154
# Time:                        00:09:32   BIC                          15258.470
# Sample:                             0   HQIC                         15255.134
#                                - 1504
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      1494.0795     12.131    123.167      0.000    1470.304    1517.855
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.26   Jarque-Bera (JB):             92715.58
# Prob(Q):                              0.61   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.33   Skew:                             1.66
# Prob(H) (two-sided):                  0.00   Kurtosis:                        41.33
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning:
#
# marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
# 평균 절대 비율 오차: 0.68
# 평균 괴리율: -0.011 %
# ========================================================================================================================
