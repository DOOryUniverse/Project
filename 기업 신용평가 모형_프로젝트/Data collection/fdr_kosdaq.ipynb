# %%
import FinanceDataReader as fdr
fdr.__version__
# Out:
# '0.9.33'

# %%
df_kosdaq = fdr.StockListing('KOSDAQ')
df_kosdaq.head()
# Out:
#     Symbol  Market    Name            Sector                  Industry  \
# 0   060310  KOSDAQ      3S          전자부품 제조업               반도체 웨이퍼 캐리어
# 3   054620  KOSDAQ  APS홀딩스            기타 금융업               인터넷 트래픽 솔루션
# 4   265520  KOSDAQ   AP시스템     특수 목적용 기계 제조업               디스플레이 제조 장비
# 5   211270  KOSDAQ    AP위성    통신 및 방송 장비 제조업                  위성통신 단말기
# 54  032790  KOSDAQ    BNGT  기계장비 및 관련 물품 도매업  Bio 이종장기 사업, ICT 프린터 현상기
#
#    ListingDate SettleMonth Representative                      HomePage Region
# 0   2002-04-23         03월            김세완          http://www.3sref.com  서울특별시
# 3   2001-12-04         12월            정기로  http://www.apsholdings.co.kr    경기도
# 4   2017-04-07         12월            김영주    http://www.apsystems.co.kr    경기도
# 5   2016-03-04         12월            류장수         http://www.apsi.co.kr  서울특별시
# 54  1997-06-26         12월            조상환       http://www.mgenplus.com  서울특별시

# %%
df_kosdaq
# Out:
#       Symbol  Market    Name                    Sector  \
# 0     060310  KOSDAQ      3S                  전자부품 제조업
# 3     054620  KOSDAQ  APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ   AP시스템             특수 목적용 기계 제조업
# 5     211270  KOSDAQ    AP위성            통신 및 방송 장비 제조업
# 54    032790  KOSDAQ    BNGT          기계장비 및 관련 물품 도매업
# ...      ...     ...     ...                       ...
# 7298  024060  KOSDAQ    흥구석유                 기타 전문 도매업
# 7299  010240  KOSDAQ      흥국             특수 목적용 기계 제조업
# 7300  189980  KOSDAQ  흥국에프엔비           비알코올음료 및 얼음 제조업
# 7305  037440  KOSDAQ      희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7307  238490  KOSDAQ      힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# ...

# %%
len(df_kosdaq)
# Out:
# 1573

# %%
com_name = df_kosdaq['Name']

# %%
com_name
# Out:
# 0           3S
# 3       APS홀딩스
# 4        AP시스템
# 5         AP위성
# 54        BNGT
#          ...
# 8036      흥구석유
# 8037        흥국
# 8038    흥국에프엔비
# 8043        희림
# 8045        힘스
# Name: Name, Length: 1573, dtype: object

# %%
len(com_name.unique())
# Out:
# 1573

# %%
com_symbol = df_kosdaq['Symbol']

# %%
type(com_symbol)
# Out:
# pandas.core.series.Series

# %%
print(com_symbol)
# Out:
# 0       060310
# 3       054620
# 4       265520
# 5       211270
# 54      032790
#          ...
# 7298    024060
# 7299    010240
# 7300    189980
# 7305    037440
# 7307    238490
# Name: Symbol, Length: 1571, dtype: object

# %%
com_symbol = com_symbol.tolist()

# %%
com_symbol
# Out:
# ['060310',
#  '054620',
#  '265520',
#  '211270',
#  '032790',
#  '013720',
#  '035760',
#  '311690',
#  '051500',
#  '058820',
#  '023460',
#  '056730',
#  '065770',
#  '083660',
#  '404950',
#  '367340',
#  '367360',
#  '068790',
#  '241520',
#  '245620',
#  '037370',
#  '050120',
#  '084180',
#  '214270',
#  '130500',
#  '900290',
#  '083450',
#  '297890',
#  '078150',
#  '195940',
#  '028300',
#  '067630',
#  '047920',
#  '115450',
#  '036640',
#  '335870',
#  '351340',
#  '388790',
#  '405350',
#  '095340',
#  '099520',
#  '950170',
#  '067290',
#  '035900',
#  '318000',
#  '024840',
#  '024120',
#  '021320',
#  '036670',
#  '044180',
#  '151860',
#  '046440',
#  '035600',
#  '226360',
#  '111870',
#  '060720',
#  '122450',
#  '052900',
#  '058400',
#  '114450',
#  '060370',
#  '108320',
#  '160550',
#  '053290',
#  '104200',
#  '060250',
#  '030190',
#  '024940',
#  '218410',
#  '327260',
#  '091340',
#  '019550',
#  '950110',
#  '046140',
#  '151910',
#  '036120',
# ...

# %%
print(com_symbol)
# Out:
# ['060310', '054620', '265520', '211270', '032790', '013720', '035760', '311690', '051500', '058820', '023460', '056730', '065770', '083660', '404950', '367340', '367360', '068790', '241520', '245620', '037370', '050120', '084180', '214270', '130500', '900290', '083450', '297890', '078150', '195940', '028300', '067630', '047920', '115450', '036640', '335870', '351340', '388790', '405350', '095340', '099520', '950170', '067290', '035900', '318000', '024840', '024120', '021320', '036670', '044180', '151860', '046440', '035600', '226360', '111870', '060720', '122450', '052900', '058400', '114450', '060370', '108320', '160550', '053290', '104200', '060250', '030190', '024940', '218410', '327260', '091340', '019550', '950110', '046140', '151910', '036120', '099220', '036540', '255220', '040610', '049470', '184230', '016250', '337450', '340350', '048550', '063440', '950180', '289080', '089230', '161570', '192410', '032540', '022220', '048770', '246690', '317240', '038340', '073570', '057030
# ...

# %%
import pandas as pd

symbol=[]
beta=[]

com_symbol = [  '060310', '054620', '265520', '211270', '032790', '013720', '035760', '311690', '051500', '058820', '023460', '056730', '065770', '083660', 
            '404950', '367340', '367360', '068790', '241520', '245620', '037370', '050120', '084180', '214270', '130500', '900290', '083450', '297890', 
            '078150', '195940', '028300', '067630', '047920', '115450', '036640', '335870', '351340', '388790', '405350', '095340', '099520', '950170', 
            '067290', '035900', '318000', '024840', '024120', '021320', '036670', '044180', '151860', '046440', '035600', '226360', '111870', '060720', 
            '122450', '052900', '058400', '114450', '060370', '108320', '160550', '053290', '104200', '060250', '030190', '024940', '218410', '327260', 
            '091340', '019550', '950110', '046140', '151910', '036120', '099220', '036540', '255220', '040610', '049470', '184230', '016250', '337450', 
            '340350', '048550', '063440', '950180', '289080', '089230', '161570', '192410', '032540', '022220', '048770', '246690', '317240', '038340', 
            '073570', '057030', '040300', '051390', '052220', '079940', '078890', '036620', '217730', '114190', '094480', '039240', '053950', '011040', 
            '024910', '198440', '049720', '014570', '348150', '098460', '035290', '038530', '900280', '215000', '121440', '366030', '014200', '029480', 
            '026910', '355150', '397880', '331520', '053270', '066620', '043650', '006050', '060480', '078130', '307750', '035080', '204020', '186230', 
            '900070', '204620', '019660', '053260', '036190', '049080', '035460', '308100', '187790', '286750', '121600', '247660', '039860', '091970', 
            '051490', '137080', '190510', '242040', '089600', '293580', '138610', '130580', '036800', '267320', '111710', '091590', '168330', '094860', 
            '253590', '212560', '095660', '042420', '950220', '311390', '085910', '092730', '290660', '306620', '153460', '007390', '033640', '330860', 
            '089140', '137940', '348210', '225570', '217270', '104620', '194700', '285490', '106520', '376930', '278650', '142280', '234690', '065560', 
            '054050', '069140', '040160', '332290', '126870', '060260', '012340', '214870', '270870', '144960', '085670', '119860', '064260', '093640', 
            '208340', '177830', '037070', '150900', '037030', '047310', '368770', '170790', '049120', '038950', '106240', '131760', '065690', '140860', 
            '091700', '032800', '318010', '027710', '225590', '054300', '068050', '222110', '263750', '251970', '087010', '119500', '389140', 
            '022100', '009520', '189690', '318020', '256630', '331380', '234100', '041020', '114630', '290720', '005670', '094940', '007330', '093380', 
            '023900', '371950', '370090', '220100', '035200', '334970', '203690', '321260', '053610', '377220', '335810', '053160', '041590', '367000', 
            '075130', '237820', '023770', '300080', '032580', '051380', '241820', '237750', '024850', '319660', '031980', '002230', '057880', '043370', 
            '239890', '347740', '137400', '128660', '006140', '376180', '304840', '062970', '087600', '161580', '347770', '163730', '332710', '341160', 
            '343510', '363260', '388220', '400560', '406760', '299030', '067310', '372290', '166090', '136480', '003380', '365590', '149980', '013030', 
            '126700', '106080', '340120', '377400', '400840', '221840', '106190', '373200', '066130', '004590', '039340', '034950', '222980', '256840', 
            '025550', '017890', '080720', '063570', '041460', '101680', '039740', '053300', '025770', '409570', '023760', '054040', '050540', '021650', 
            '053590', '032300', '037230', '030520', '052600', '256150', '092460', '047080', '070590', '226440', '042520', '078350', '045100', '046110', 
            '024740', '005860', '123840', '007770', '043090', '079170', '086960', '054920', '002680', '386580', '034810', '076610',  
            '059270', '220180', '900270', '084990', '170030', '319400', '048410', '052260', '016790', '041440', '039010', '090850', '092300', '138360', 
            '011080', '060560', '064240', '039610', '126640', '061250', '097870', '290270', '353190', '090710', '205470', '115160', '028080', 
            '032860', '200670', '065510', '215090', '263920', '243070', '084110', '145020', '024060', '010240', '189980', '037440', '238490'
            ]

# %%
for i in com_symbol:

    url = "https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=" + i
    
    #베타 계수 긁기
    tables = pd.read_html(url, encoding='utf-8', match='52주베타')
    if tables:
        tables_1 = str(tables)
        tables_2 = tables_1.split(sep='\n6')[0]
        tables_3 = float(tables_2.split(sep='52주베타')[1])

        symbol.append(i)
        beta.append(tables_3)

# %%
#표로 만들기
beta = pd.DataFrame({'회사심볼': symbol, 
                    '베타계수': beta})

print(beta.head())
# Out:
#      회사심볼  베타계수
# 0  060310  1.36
# 1  054620  1.61
# 2  265520  1.07
# 3  211270  1.18
# 4  032790  0.00

# %%
beta.shape
# Out:
# (1557, 2)

# %%
beta.to_excel('베타계수.xlsx')

# %%
#fdr에서는 심볼로 나왓지만 네이버금융에서는 검색이 안되는 심볼들
a = ['673921C', 
'673921B',
'234421A', 
'110821B', 
'543021A',
'437121A',
'6679217',
'4963229',
'4204217',
'7661219',
'1957229',
'8280218'
]
b = []
c = []

for i in a:

    url = "https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=" + i
    
    #베타 계수 긁기
    tables = pd.read_html(url, encoding='utf-8', match='52주베타')
    if tables:
        tables_1 = str(tables)
        tables_2 = tables_1.split(sep='\n6')[0]
        tables_3 = float(tables_2.split(sep='52주베타')[1])

        b.append(i) #회사심볼 저장
        c.append(tables_3) #회사 베타계수 저장

#표로 만들기
d = pd.DataFrame({'회사심볼': b, 
                    '베타계수': c})

print(d.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/6b/73dpm1vs05v8n2ng962nmn2h0000gn/T/ipykernel_77555/3749010862.py in <module>
#      20
#      21     #베타 계수 긁기
# ---> 22     tables = pd.read_html(url, encoding='utf-8', match='52주베타')
#      23     if tables:
#      24         tables_1 = str(tables)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1096     io = stringify_path(io)
#    1097
# ...
