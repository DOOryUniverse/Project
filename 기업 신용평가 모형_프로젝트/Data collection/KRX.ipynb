# %%
import FinanceDataReader as fdr
df_krx = fdr.StockListing('KRX')
df_krx.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S         전자부품 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth     Representative                       HomePage Region
# 0         03월                김세완           http://www.3sref.com  서울특별시
# 1         12월           박대현, 손삼달         http://www.ajnet.co.kr  서울특별시
# 2         12월  채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                김영주     http://www.apsystems.co.kr    경기도

# %%
KOSDAQ=df_krx[df_krx['Market']=='KOSDAQ']

# %%
KOSDAQ['Symbol']
# Out:
# 0       060310
# 3       054620
# 4       265520
# 5       211270
# 53      032790
#          ...
# 8033    024060
# 8034    010240
# 8035    189980
# 8040    037440
# 8042    238490
# Name: Symbol, Length: 1573, dtype: object

# %%
KOSDAQ.to_csv('./KOSDAQ.csv',index=False,encoding='utf-8-sig')

# %%
df_krx['Market'].value_counts()# 6346 1573 126
# Out:
# KOSPI     6344
# KOSDAQ    1573
# KONEX      126
# Name: Market, dtype: int64

# %%
import pandas as pd
KOSDAQ=pd.read_csv('./KOSDAQ.csv')

# %%
KOSDAQ['Symbol']
# Out:
# 0        60310
# 1        54620
# 2       265520
# 3       211270
# 4        32790
#          ...
# 1568     24060
# 1569     10240
# 1570    189980
# 1571     37440
# 1572    238490
# Name: Symbol, Length: 1573, dtype: object

# %%
import OpenDartReader

api_key = '	025a6f8daa947050d01077a3c7104fff3a3f661f'

dart = OpenDartReader(api_key)

# %%
a[1]
a[2]

# %%
dart.finstate('삼성전자', 2021)
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 1   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 2   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 3   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 4   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 5   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 6   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 7   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 8   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 9   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 10  20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# ...

# %%
a=[]
for i in range(len(KOSDAQ['Name'])):
    if "스팩" in KOSDAQ['Name'][i]:
        a.append(i)

# %%
a
# Out:
# [14,
#  15,
#  16,
#  35,
#  36,
#  37,
#  38,
#  83,
#  84,
#  127,
#  128,
#  129,
#  228,
#  229,
#  230,
#  415,
#  416,
#  418,
#  505,
#  506,
#  525,
#  634,
#  635,
#  636,
#  641,
#  642,
#  643,
#  644,
#  797,
#  826,
#  827,
#  867,
#  868,
#  869,
#  870,
#  1036,
#  1037,
#  1043,
#  1044,
#  1045,
#  1069,
#  1239,
#  1327,
#  1461,
#  1462,
#  1463,
#  1464,
#  1465,
#  1466,
#  1467,
#  1470,
#  1478,
#  1479,
#  1480,
#  1499,
#  1527]

# %%
KOSDAQ['Name']
# Out:
# 0           3S
# 3       APS홀딩스
# 4        AP시스템
# 5         AP위성
# 53        BNGT
#          ...
# 8035      흥구석유
# 8036        흥국
# 8037    흥국에프엔비
# 8042        희림
# 8044        힘스
# Name: Name, Length: 1573, dtype: object

# %%
kosdaq=fdr.StockListing('KOSDAQ')

# %%
kosdaq.shape
# Out:
# (1573, 10)

# %%
kosdaq
# Out:
#       Symbol  Market    Name                    Sector  \
# 0     060310  KOSDAQ      3S                  전자부품 제조업
# 3     054620  KOSDAQ  APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ   AP시스템             특수 목적용 기계 제조업
# 5     211270  KOSDAQ    AP위성            통신 및 방송 장비 제조업
# 53    032790  KOSDAQ    BNGT          기계장비 및 관련 물품 도매업
# ...      ...     ...     ...                       ...
# 8035  024060  KOSDAQ    흥구석유                 기타 전문 도매업
# 8036  010240  KOSDAQ      흥국             특수 목적용 기계 제조업
# 8037  189980  KOSDAQ  흥국에프엔비           비알코올음료 및 얼음 제조업
# 8042  037440  KOSDAQ      희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 8044  238490  KOSDAQ      힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# ...

# %%
a=[]
for i in range(len(kosdaq['Name'])):
    if "스팩" in kosdaq['Name'][i]:
        a.append(i)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\taehwan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/taehwan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///c%3A/Users/taehwan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/taehwan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File c:\Users\taehwan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
a.shape
