# %%
import FinanceDataReader as fdr
df_krx = fdr.StockListing('KRX')

KOSDAQ=df_krx[df_krx['Market']=='KOSDAQ']

KOSDAQ.to_csv('./KOSDAQ.csv',index=False,encoding='utf-8-sig')

import pandas as pd
KOSDAQ=pd.read_csv('./KOSDAQ.csv')

import OpenDartReader

api_key = '	4cf147f9e5c9916736cd84370f3f51b0a4c3d94f'
import dart_fss as dart
dart = OpenDartReader(api_key)

# %%
a =KOSDAQ["Symbol"].values.tolist()

# %%
a
# Out:
# ['060310',
#  '054620',
#  '265520',
#  '211270',
#  '032790',
#  '013720',
#  '035760',
#  '311690',
#  '051500',
#  '058820',
#  '023460',
#  '056730',
#  '065770',
#  '083660',
#  '404950',
#  '367340',
#  '367360',
#  '068790',
#  '241520',
#  '245620',
#  '037370',
#  '050120',
#  '084180',
#  '214270',
#  '130500',
#  '900290',
#  '083450',
#  '297890',
#  '078150',
#  '195940',
#  '028300',
#  '067630',
#  '047920',
#  '115450',
#  '036640',
#  '335870',
#  '351340',
#  '388790',
#  '405350',
#  '095340',
#  '099520',
#  '950170',
#  '067290',
#  '035900',
#  '318000',
#  '024840',
#  '024120',
#  '021320',
#  '036670',
#  '044180',
#  '151860',
#  '046440',
#  '035600',
#  '226360',
#  '111870',
#  '060720',
#  '122450',
#  '052900',
#  '058400',
#  '114450',
#  '060370',
#  '108320',
#  '160550',
#  '053290',
#  '104200',
#  '060250',
#  '030190',
#  '024940',
#  '218410',
#  '327260',
#  '091340',
#  '019550',
#  '950110',
#  '046140',
#  '151910',
#  '036120',
# ...

# %%
for i in range(0,1573,1):
   dart.finstate(KOSDAQ["Name"].values, 2019)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12196/1962019651.py in <module>
#       1 for i in range(0,1573,1):
# ----> 2    dart.finstate(KOSDAQ["Name"].values, 2019)
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenDartReader\dart.py in finstate(self, corp, bsns_year, reprt_code)
#     103             corp_code = ','.join(code_list)
#     104         else:
# --> 105             corp_code = self.find_corp_code(corp)
#     106         return dart_finstate.finstate(self.api_key, corp_code, bsns_year, reprt_code)
#     107
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenDartReader\dart.py in find_corp_code(self, corp)
#      83     # 1-4. 공시정보 - 고유번호: corp(종목코드 혹은 회사이름) to 고유번호(corp_code)
#      84     def find_corp_code(self, corp):
# ---> 85         if not corp.isdigit():
# ...

# %%
dart.finstate("공구우먼", 2019)

# %%
import pandas as pd
text = pd.read_csv("./2021_사업보고서_01_재무상태표_연결_20220503.txt", encoding = "CP949")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12196/76933578.py in <module>
#       1 import pandas as pd
# ----> 2 text = pd.read_csv("./2021_사업보고서_01_재무상태표_연결_20220503.txt", encoding = "CP949")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd
data  = pd.read_csv("./basic_final_df.csv")

# %%
data.shape
# Out:
# (18437, 162)

# %%
data.to_csv("./2기자료 원본.csv", index = False,encoding='CP949')

# %%
data
# Out:
#        차기부도여부  총자본증가율  유형자산증가율  유동자산증가율  영업이익증가율  순이익증가율  재고자산증가율  자기자본증가율  \
# 0           0  120.08   215.25    29.79     0.00    0.00     0.00   193.28
# 1           0   56.55    55.67    86.84     0.00    0.00   445.64    19.57
# 2           0  -33.92    -8.50   -41.24     0.00    0.00    42.07   -61.98
# 3           0    5.66   -11.92    18.08     0.00    0.00    18.70    82.10
# 4           0   14.18     7.86    31.54     0.00    0.00    -4.87     6.72
# ...       ...     ...      ...      ...      ...     ...      ...      ...
# 15162       0   -4.74    -0.42   -20.97     0.00  -49.37     3.58     0.75
# 15163       0   -2.83    -8.83    32.81     0.00  145.44   -42.39     2.23
# 15164       0   12.89    -0.74   -15.96   -60.19   63.95   -23.42     3.11
# 15165       0    1.39    -5.61     7.35   108.43  -25.71    52.46     1.39
# 15166       0    0.98    -0.56     7.34   -22.03   -5.19     9.41     0.83
#
# ...
